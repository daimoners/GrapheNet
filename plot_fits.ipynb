# %% [markdown]
# # Production plots

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)

# %%
data_df = pd.read_csv('/home/tommaso/git_workspace/GrapheNet/data_GO/training_dataset_reference/dataset.csv', header=0)
data_G_df = pd.read_csv('/home/tommaso/git_workspace/GrapheNet/data_G/training_dataset_reference/dataset_with_energy_per_atom_new.csv', header=0)

# %%
def r2_score(y_pred: list, y_true: list):
    y_pred = np.array(y_pred)
    y_true = np.array(y_true)
    mean_y = np.mean(y_true)
    SSR = np.sum((y_pred - y_true) ** 2)
    SST = np.sum((y_true - mean_y) ** 2)
    return 1 - SSR / SST

# %% [markdown]
# ## Electron affinity GO

# %%
bound = [-7.5, -4.2]

target = "electron_affinity"

df = pd.read_csv(f"/home/tommaso/git_workspace/GrapheNet/data_GO/training_dataset_reference/models/inceptionresnet/last_high_reduced_layers_lr_workstation_optimized/{target}_new/{target}_prediction_results.csv", header=0)

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 5), gridspec_kw={'width_ratios': [4, 1]})

# Plot the scatter plot on the left subplot
ax1.scatter(df['electron_affinity_predicted'], df['electron_affinity_real'], s=20, alpha=0.3,linewidth=0)
ax1.set_xlabel('EA (eV) - predicted',size=20)
ax1.set_ylabel('EA (eV) - true',size=20)

ax1.tick_params(axis='both', which='major', labelsize=20)

#ax1.axis('equal')
ax1.set_xlim(bound)
ax1.set_ylim(bound)
ax1.set_box_aspect(1)

# Add y=x reference axis
lowbound1 = bound[0]*0.98
lowbound2 = bound[1]*1.02
lowbound = [lowbound1, lowbound2]
ax1.plot(lowbound, lowbound)

# Plot the histogram on the right subplot
ax2.set_ylim(bound)
hist_data=data_df['electron_affinity']
w=0.01
ax2.hist(hist_data, orientation='horizontal',bins=np.arange(min(hist_data), max(hist_data) + w, w),linewidth=0,alpha=0.6)
ax2.tick_params(axis='both', which='major', labelsize=20)
ax2.set_xticks([])
ax2.yaxis.tick_right()
# Adjust the position of the subplots
fig.subplots_adjust(wspace=-0.4)

# Show the plot
plt.show()

print(f"R2 fit: {r2_score(df['electron_affinity_predicted'].to_list(),df['electron_affinity_real'].to_list())}")
# Out:
# R2 fit: 0.7461510234029625

# %% [markdown]
# ## Ionization potential - GO

# %%
bound = [-5.6, -3.5]

target = "ionization_potential"

df = pd.read_csv(f"/home/tommaso/git_workspace/GrapheNet/data_GO/training_dataset_reference/models/inceptionresnet/last_high_reduced_layers_lr_workstation_optimized/{target}/{target}_prediction_results.csv", header=0)

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 5), gridspec_kw={'width_ratios': [4, 1]})

# Plot the scatter plot on the left subplot
ax1.scatter(df['ionization_potential_predicted'], df['ionization_potential_real'], s=20, alpha=0.3,linewidth=0)
ax1.set_xlabel('IP (eV) - predicted',size=20)
ax1.set_ylabel('IP (eV) - true',size=20)

ax1.tick_params(axis='both', which='major', labelsize=20)

#ax1.axis('equal')
ax1.set_xlim(bound)
ax1.set_ylim(bound)
ax1.set_box_aspect(1)

# Add y=x reference axis
lowbound1 = bound[0]*0.98
lowbound2 = bound[1]*1.02
lowbound = [lowbound1, lowbound2]
ax1.plot(lowbound, lowbound)

# Plot the histogram on the right subplot
ax2.set_ylim(bound)
hist_data=data_df['ionization_potential']
w=0.01
ax2.hist(hist_data, orientation='horizontal',bins=np.arange(min(hist_data), max(hist_data) + w, w),linewidth=0,alpha=0.6)
ax2.tick_params(axis='both', which='major', labelsize=20)
ax2.set_xticks([])
ax2.yaxis.tick_right()
# Adjust the position of the subplots
fig.subplots_adjust(wspace=-0.4)

# Show the plot
plt.show()

print(f"R2 fit: {r2_score(df['ionization_potential_predicted'].to_list(),df['ionization_potential_real'].to_list())}")
# Out:
# R2 fit: 0.8363921705809152

# %% [markdown]
# ## Electronegativity - GO

# %%
bound = [-6.3, -4.1]

target = "electronegativity"

df = pd.read_csv(f"/home/tommaso/git_workspace/GrapheNet/data_GO/training_dataset_reference/models/inceptionresnet/last_high_reduced_layers_lr_workstation_optimized/{target}/{target}_prediction_results.csv", header=0)

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 5), gridspec_kw={'width_ratios': [4, 1]})

# Plot the scatter plot on the left subplot
ax1.scatter(df['electronegativity_predicted'], df['electronegativity_real'], s=20, alpha=0.3,linewidth=0)
ax1.set_xlabel('X (eV) - predicted',size=20)
ax1.set_ylabel('X (eV) - true',size=20)

ax1.tick_params(axis='both', which='major', labelsize=20)

#ax1.axis('equal')
ax1.set_xlim(bound)
ax1.set_ylim(bound)
ax1.set_box_aspect(1)

# Add y=x reference axis
lowbound1 = bound[0]*0.98
lowbound2 = bound[1]*1.02
lowbound = [lowbound1, lowbound2]
ax1.plot(lowbound, lowbound)

# Plot the histogram on the right subplot
ax2.set_ylim(bound)
hist_data=data_df['electronegativity']
w=0.01
ax2.hist(hist_data, orientation='horizontal',bins=np.arange(min(hist_data), max(hist_data) + w, w),linewidth=0,alpha=0.6)
ax2.tick_params(axis='both', which='major', labelsize=20)
ax2.set_xticks([])
ax2.yaxis.tick_right()
# Adjust the position of the subplots
fig.subplots_adjust(wspace=-0.4)

# Show the plot
plt.show()

print(f"R2 fit: {r2_score(df['electronegativity_predicted'].to_list(),df['electronegativity_real'].to_list())}")
# Out:
# R2 fit: 0.7936098942941301

# %% [markdown]
# ## Fermi energy - GO

# %%
bound = [-6.1, -4.5]

target = "Fermi_energy"

df = pd.read_csv(f"/home/tommaso/git_workspace/GrapheNet/data_GO/training_dataset_reference/models/inceptionresnet/last_high_reduced_layers_lr_workstation_optimized/{target}/{target}_prediction_results.csv", header=0)

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 5), gridspec_kw={'width_ratios': [4, 1]})

# Plot the scatter plot on the left subplot
ax1.scatter(df['Fermi_energy_predicted'], df['Fermi_energy_real'], s=20, alpha=0.3,linewidth=0)
ax1.set_xlabel('Ef (eV) - predicted',size=20)
ax1.set_ylabel('Ef (eV) - true',size=20)

ax1.tick_params(axis='both', which='major', labelsize=20)

#ax1.axis('equal')
ax1.set_xlim(bound)
ax1.set_ylim(bound)
ax1.set_box_aspect(1)

# Add y=x reference axis
lowbound1 = bound[0]*0.98
lowbound2 = bound[1]*1.01
lowbound = [lowbound1, lowbound2]
ax1.plot(lowbound, lowbound)

# Plot the histogram on the right subplot
ax2.set_ylim(bound)
hist_data=data_df['Fermi_energy']
w=0.01
ax2.hist(hist_data, orientation='horizontal',bins=np.arange(min(hist_data), max(hist_data) + w, w),linewidth=0,alpha=0.6)
ax2.tick_params(axis='both', which='major', labelsize=20)
ax2.set_xticks([])
ax2.yaxis.tick_right()
# Adjust the position of the subplots
fig.subplots_adjust(wspace=-0.4)

# Show the plot
plt.show()

print(f"R2 fit: {r2_score(df['Fermi_energy_predicted'].to_list(),df['Fermi_energy_real'].to_list())}")
# Out:
# R2 fit: 0.9204223761845709

# %% [markdown]
# ## Formation energy - GO

# %%
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)

bound = [-15, -1]

target = "formation_energy"

df = pd.read_csv(f"/home/tommaso/git_workspace/GrapheNet/data_GO/training_dataset_reference/models/inceptionresnet/last_high_reduced_layers_lr_workstation_optimized/{target}_new/{target}_prediction_results.csv", header=0)

# Create a figure with two subplots
fig, (axe1, axe2) = plt.subplots(ncols=2, figsize=(10, 5), gridspec_kw={'width_ratios': [4, 1]})

# Plot the scatter plot on the left subplot
axe1.scatter(df['formation_energy_predicted']/1000, df['formation_energy_real']/1000, s=20, alpha=0.1,linewidth=0)
axe1.set_xlabel('Eform (eV*1E3) - predicted',size=20)
axe1.set_ylabel('Eform (eV*1E3) - true',size=20)

axe1.tick_params(axis='both', which='major', labelsize=20)
axe1.xaxis.set_major_locator(MultipleLocator(5.0))
axe1.yaxis.set_major_locator(MultipleLocator(5.0))
axe1.axis('equal')
axe1.set_xlim(bound)
axe1.set_ylim(bound)
axe1.set_box_aspect(1)

# Add y=x reference axis
lowbound1 = bound[0]*0.95
lowbound2 = bound[1]*1.35
lowbound = [lowbound1, lowbound2]
axe1.plot(lowbound, lowbound)

# Plot the histogram on the right subplot
hist_ene_data=data_df['formation_energy']/1000
w=0.02
axe2.hist(hist_ene_data, orientation='horizontal',bins=np.arange(min(hist_ene_data), max(hist_ene_data) + w, w),linewidth=0,alpha=0.6)
axe2.set_ylim(bound)
#axe2.set_xlim([0,20])
axe2.tick_params(axis='both', which='major', labelsize=20)
#axe2.set_xticks([])
axe2.yaxis.tick_right()
# Adjust the position of the subplots
fig.subplots_adjust(wspace=-0.4)

# Show the plot
plt.show()

print(f"R2 fit: {r2_score(df['formation_energy_predicted'].to_list(),df['formation_energy_real'].to_list())}")
# Out:
# R2 fit: 0.9990989633234317

# %% [markdown]
# ## Total energy - DG

# %%
bound = [-4.4, -1.6]

target = "total_energy"

df = pd.read_csv(f"/home/tommaso/git_workspace/GrapheNet/data_G/training_dataset_reference/models/{target}/{target}_prediction_results.csv", header=0)

# Create a figure with two subplots
fig, (axe1, axe2) = plt.subplots(ncols=2, figsize=(10, 5), gridspec_kw={'width_ratios': [4, 1]})

# Plot the scatter plot on the left subplot
axe1.scatter(df['total_energy_predicted']/1000, df['total_energy_real']/1000, s=20, alpha=0.3,linewidth=0)
axe1.set_xlabel('Etot (eV*1E3) - predicted',size=20)
axe1.set_ylabel('Etot (eV*1E3) - true',size=20)

axe1.tick_params(axis='both', which='major', labelsize=20)
axe1.xaxis.set_major_locator(MultipleLocator(1.0))
axe1.yaxis.set_major_locator(MultipleLocator(1.0))
axe1.axis('equal')
axe1.set_xlim(bound)
axe1.set_ylim(bound)
axe1.set_box_aspect(1)

# Add y=x reference axis
lowbound1 = bound[0]*0.95
lowbound2 = bound[1]*1.05
lowbound = [lowbound1, lowbound2]
axe1.plot(lowbound, lowbound)

# Plot the histogram on the right subplot
hist_ene_data=data_G_df['total_energy']/1000
w=0.01
axe2.hist(hist_ene_data, orientation='horizontal',bins=np.arange(min(hist_ene_data), max(hist_ene_data) + w, w),linewidth=0,alpha=0.6)
axe2.set_ylim(bound)
#axe2.set_xlim([0,20])
axe2.tick_params(axis='both', which='major', labelsize=20)
#axe2.set_xticks([])
axe2.yaxis.tick_right()
# Adjust the position of the subplots
fig.subplots_adjust(wspace=-0.4)

# Show the plot
plt.show()

print(f"R2 fit: {r2_score(df['total_energy_predicted'].to_list(),df['total_energy_real'].to_list())}")
# Out:
# R2 fit: 0.9999287216605041

# %% [markdown]
# ## Energy per Atom - DG

# %%
bound = [-9.2, -8.45]

target = "energy_per_atom"

df = pd.read_csv(f"/home/tommaso/git_workspace/GrapheNet/data_G/training_dataset_reference/models/{target}/{target}_prediction_results.csv", header=0)

# Create a figure with two subplots
fig, (axe1, axe2) = plt.subplots(ncols=2, figsize=(10, 5), gridspec_kw={'width_ratios': [4, 1]})

# Plot the scatter plot on the left subplot
axe1.scatter(df['energy_per_atom_predicted'], df['energy_per_atom_real'], s=20, alpha=0.3,linewidth=0)
axe1.set_xlabel('Eatom (eV) - predicted',size=20)
axe1.set_ylabel('Eatom (eV) - true',size=20)

axe1.tick_params(axis='both', which='major', labelsize=20)
axe1.xaxis.set_major_locator(MultipleLocator(1.0))
axe1.yaxis.set_major_locator(MultipleLocator(1.0))
axe1.axis('equal')
axe1.set_xlim(bound)
axe1.set_ylim(bound)
axe1.set_box_aspect(1)

# Add y=x reference axis
lowbound1 = bound[0]*0.923
lowbound2 = bound[1]*1.085
lowbound = [lowbound1, lowbound2]
axe1.plot(lowbound, lowbound)

# Plot the histogram on the right subplot
hist_ene_data=data_G_df['energy_per_atom']
w=0.01
axe2.hist(hist_ene_data, orientation='horizontal',bins=np.arange(min(hist_ene_data), max(hist_ene_data) + w, w),linewidth=0,alpha=0.6)
axe2.set_ylim(bound)
#axe2.set_xlim([0,20])
axe2.tick_params(axis='both', which='major', labelsize=20)
#axe2.set_xticks([])
axe2.yaxis.tick_right()
# Adjust the position of the subplots
fig.subplots_adjust(wspace=-0.4)

# Show the plot
plt.show()

print(f"R2 fit: {r2_score(df['energy_per_atom_predicted'].to_list(),df['energy_per_atom_real'].to_list())}")
# Out:
# R2 fit: 0.9912562290909395

# %% [markdown]
# ## Distribution of formation (GO) and energy per atom (DG) as a function of composition

# %%
df = pd.read_csv("/home/tommaso/xyz_files_GO/dataset_with_formation_energy.csv", header=0)

# Creare un diagramma di dispersione con linea di regressione
sns.regplot(x='formation_energy', y='atom_number_total', data=df, line_kws={'color': 'blue'})

# Aggiungere titolo e label agli assi
#plt.title('Correlation GO')
plt.xlabel('Formation Energy (eV)')
plt.ylabel('Total number of atoms')

# Mostrare il plot
plt.show()

# %%
df = pd.read_csv("/home/tommaso/xyz_files_GO/dataset_with_formation_energy.csv", header=0)

# Creare un diagramma di dispersione con linea di regressione
sns.regplot(x='formation_energy', y='O', data=df, line_kws={'color': 'blue'})

# Aggiungere titolo e label agli assi
#plt.title('Correlation GO, oxygen only')
plt.xlabel('Formation Energy (eV)')
plt.ylabel('Number of oxygen atoms')

# Mostrare il plot
plt.show()

# %%
df = pd.read_csv("/home/tommaso/xyz_files_GO/dataset_with_formation_energy.csv", header=0)

# Creare un diagramma di dispersione con linea di regressione
sns.regplot(x='formation_energy', y='H', data=df, line_kws={'color': 'blue'})

# Aggiungere titolo e label agli assi
#plt.title('Correlation GO, oxygen only')
plt.xlabel('Formation Energy (eV)')
plt.ylabel('Number of hydrogen atoms')

# Mostrare il plot
plt.show()

# %%
df = pd.read_csv("/home/tommaso/xyz_files_GO/dataset_with_formation_energy.csv", header=0)

# Creare un diagramma di dispersione con linea di regressione
sns.regplot(x='formation_energy', y='C', data=df, line_kws={'color': 'blue'})

# Aggiungere titolo e label agli assi
#plt.title('Correlation GO, oxygen only')
plt.xlabel('Formation Energy (eV)')
plt.ylabel('Number of carbon atoms')

# Mostrare il plot
plt.show()

# %%
df = pd.read_csv('/home/tommaso/git_workspace/GrapheNet/data_G/training_dataset_reference/dataset_with_energy_per_atom_new.csv', header=0)

# Creare un diagramma di dispersione con linea di regressione
sns.regplot(x='energy_per_atom', y='C', data=df, line_kws={'color': 'blue'})

# Aggiungere titolo e label agli assi
#plt.title('Correlation G')
plt.xlabel('Energy per atom (eV)')
plt.ylabel('Nmber of carbon atoms')

# Mostrare il plot
plt.show()

# %%
# from pathlib import Path

# df = pd.read_csv('/home/tommaso/git_workspace/GrapheNet/data_G/training_dataset_reference/dataset_with_energy_per_atom.csv', header=0)
# dataset_path = Path("/home/tommaso/git_workspace/GrapheNet/data_G/training_dataset_reference")

# names = df["file_name"].to_list()
# atoms = []

# for name in names:
#     for dir in ["train","test","val"]:
#         for sample in dataset_path.joinpath(dir).iterdir():
#             if sample.suffix == ".txt" and sample.stem == name:
#                 atoms.append(np.loadtxt(sample))
#                 break
            
# df["C"] = atoms
# df.to_csv('/home/tommaso/git_workspace/GrapheNet/data_G/training_dataset_reference/dataset_with_energy_per_atom_new.csv', index=False)

# %% [markdown]
# ## Correlation between total energy and the local distribution of oxygen, computed as xxx, in GO samples

# %%
df = pd.read_csv("/home/tommaso/xyz_files_GO/dataset_with_formation_energy.csv", header=0)

correlation = df["total_energy"].corr(df["distribution_mean"])

# Plot Heatmap
#plt.figure(figsize=(8, 6))
sns.heatmap(df[["total_energy", "distribution_mean"]].corr().values,
            annot=True, cmap='coolwarm', fmt='.2f',
            xticklabels=["Etot", "Distribution Mean"],
            yticklabels=["Etot", "Distribution Mean"])
plt.show()

# %%
df = pd.read_csv("/home/tommaso/xyz_files_GO/dataset_with_formation_energy.csv", header=0)
# Plot Regplot
#plt.figure(figsize=(8, 6))
sns.regplot(x='total_energy', y='distribution_mean', data=df, scatter_kws={'s': 100}, line_kws={'color': 'blue'})
plt.xlabel('Etot (eV)')
plt.ylabel('Distribution Mean')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score
import seaborn as sns
from pathlib import Path
import yaml

plt.style.use("seaborn-v0_8-paper")

# %%
def plot_loss_acc(train_values: list, val_values: list, dpath: Path, type: str = "Loss"):
        epochs = list(range(1, len(train_values) + 1))

        data = pd.DataFrame({"Epoch": epochs, f"Train_{type}": train_values, f"Val_{type}": val_values})

        # Usa Seaborn per creare il grafico
        fig = plt.figure(figsize=(10, 7))
        #sns.lineplot(x="Epoch", y=f"{type}", data=data)
        sns.lineplot(x="Epoch", y=f"Train_{type}", data=data, label=f"Train {type}", color="blue")
        sns.lineplot(x="Epoch", y=f"Val_{type}", data=data, label=f"Val {type}", color="red")

        # Aggiungi etichette e titolo
        plt.xlabel("Epoch", fontsize=20)
        plt.ylabel(f"{type}", fontsize=20)
        plt.tick_params(axis="both", which="major", labelsize=20)
        plt.savefig(str(dpath), dpi=300, bbox_inches="tight")

# %%
targets = ["electron_affinity", "electronegativity", "energy_per_atom","Fermi_energy","formation_energy","ionization_potential","total_energy"]
models_path = Path("/home/tommaso/git_workspace/GrapheNet/data_paper/data_GO/training_dataset_reference/models_padding")
plot_path = Path("/home/tommaso/git_workspace/GrapheNet/data_paper/data_GO/training_dataset_reference/plots")
for target in targets:
    with open(str(models_path.joinpath(target,f"{target}_train_results.yaml")),"r") as file:
        results = yaml.safe_load(file)
    
    train_acc = results["train_acc"]
    train_loss = results["train_loss"]
    val_acc = results["val_acc"]
    val_loss = results["val_loss"]
    
    plot_loss_acc(train_acc, val_acc, plot_path.joinpath(f"{target}_train_acc.png"),type="Accuracy")
    plot_loss_acc(train_loss, val_loss, plot_path.joinpath(f"{target}_train_loss.png"))
# Out:
# /home/tommaso/miniconda3/envs/pl/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/tommaso/miniconda3/envs/pl/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/tommaso/miniconda3/envs/pl/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
from tqdm import tqdm
from pathlib import Path

target = "electronegativity"
dataset = Path("/home/tommaso/git_workspace/GrapheNet/data_paper/Coulomb_GO/subset_training_dataset_500/test")
df = pd.read_csv(dataset.parent.joinpath("models_norm_z_score",target,f"{target}_prediction_results.csv"))

file_names = df["file_name"].to_list()
num_atoms = []

for file in tqdm(file_names):
    n = np.loadtxt(dataset.joinpath(f"{file}.txt"))
    num_atoms.append(np.sum(n))

df["num_atoms"] = num_atoms

sns.scatterplot(x=f'{target}_MAE', y='num_atoms', data=df, s=70)
plt.xlabel(f'{target}_MAE')
plt.ylabel('Total number of atoms')
# Out:
# 100%|██████████| 436/436 [00:00<00:00, 8898.17it/s]
# /home/tommaso/miniconda3/envs/pl/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/tommaso/miniconda3/envs/pl/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0, 0.5, 'Total number of atoms')
